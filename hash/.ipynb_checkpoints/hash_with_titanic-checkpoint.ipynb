# %%
import pandas as pd
import hashlib
import random

# %%
train = pd.read_csv('train.csv')
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(hashlib.algorithms_available)
# Out:
# {'sha', 'whirlpool', 'SHA512', 'sha3_256', 'dsaWithSHA', 'sha3_512', 'sha3_384', 'SHA1', 'DSA-SHA', 'sha256', 'sha224', 'ecdsa-with-SHA1', 'SHA224', 'MD4', 'dsaEncryption', 'ripemd160', 'sha3_224', 'SHA384', 'sha512', 'shake_256', 'SHA', 'md5', 'sha384', 'RIPEMD160', 'sha1', 'blake2b', 'MD5', 'shake_128', 'DSA', 'md4', 'SHA256', 'blake2s'}

# %% [markdown]
# ## Function for Salt with random number

# %%
def salt(text):
    return text+str(random.randint(1,512))

# %% [markdown]
# ## Hashing the name with sha512 and random salt

# %%
temp_df = pd.DataFrame()
for index, row in train.iterrows():
    temp_df.loc[index,'hashed_name'] = hashlib.sha512(salt(row['Name']).encode('utf-8')).hexdigest()
train = pd.concat([train, temp_df], axis=1, sort=False)
train.drop('Name',axis=1,inplace=True)

# %% [markdown]
# ## Hashing the ticket with sha3_512 and random salt

# %%
temp_df = pd.DataFrame()
for index, row in train.iterrows():
    temp_df.loc[index,'hashed_ticket'] = hashlib.sha3_512(salt(row['Ticket']).encode('utf-8')).hexdigest()
train = pd.concat([train, temp_df], axis=1, sort=False)
train.drop('Ticket',axis=1,inplace=True)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# 0            1         0       3    male  22.0      1      0   7.2500   NaN
# 1            2         1       1  female  38.0      1      0  71.2833   C85
# 2            3         1       3  female  26.0      0      0   7.9250   NaN
# 3            4         1       1  female  35.0      1      0  53.1000  C123
# 4            5         0       3    male  35.0      0      0   8.0500   NaN
#
#   Embarked                                        hashed_name  \
# 0        S  ced225e947ec3d371d0fa3a8e5f4e21346c6f59266617e...
# 1        C  573c20293b5f322f4132c32c4322811cae3173af789466...
# 2        S  64bfb6f5e57ccc3575b541c65d3db7d0a062cd70d4d6f2...
# 3        S  227bdd29fb7c92cf0b0d1721dc4df1899f5b3a22f9cfc8...
# 4        S  d854aa962a4d5e95d52bbddd7b076cc2d3235db7999f1a...
#
#                                        hashed_ticket
# 0  0db309a69dab60ba5f60e7829c7121cc6ea3b17301a3d5...
# 1  c4627b9896faee6c27e1ef5f4c92b2874afa1a237a1f2a...
# 2  5893f7447530557a5488326c82c01e1c786e4b4274f476...
# 3  4a13ac1e5e879d3d8266ae0b69a6601f767030ceb05c70...
# 4  cbcf9301ed5ae13d7624e0ae7e67fc3e4a6bb865a3b081...

# %%
train.to_csv('hashed.csv')
